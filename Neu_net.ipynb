# %%
from tensorflow.keras.datasets import fashion_mnist
from ensorftlow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
weel_clf = pd.read_csv('C://Users/SMA_9/Desktop/HW/train.csv', index_col=0 )
weel_clf = weel_clf.set_index(['well'])
weel_clf
# Out:
#       typic
# well
# 280       1
# 281       1
# 291       1
# 292       1
# 293       1
# ...     ...
# 474       4
# 491       4
# 435      10
# 434       9
# 549       5
#
# [87 rows x 1 columns]

# %%
x_train = []
y_train = []
for well in weel_clf.index:
    SP = pd.read_csv('C://Users/SMA_9/Desktop/HW/OutData2/' + well +'.csv' )
    x_train.append(SP.X.values)
    typic_c = np.array([0,0,0,0,0,0,0,0], dtype=float)
    if weel_clf.typic[well] == 1: 
        typic_c[0] = 1
    elif weel_clf.typic[well] == 2:
        typic_c[1] = 1
    elif weel_clf.typic[well] == 3:
        typic_c[2] = 1
    elif weel_clf.typic[well] == 4 or weel_clf.typic[well] == 5 or weel_clf.typic[well] == 6 :
        typic_c[3] = 1
    elif weel_clf.typic[well] == 7:
        typic_c[4] = 1
    elif weel_clf.typic[well] == 8:
        typic_c[5] = 1
    elif weel_clf.typic[well] == 9:
        typic_c[6] = 1
    elif weel_clf.typic[well] == 10:
        typic_c[7] = 1
    y_train.append(typic_c)

# %%
x_train = np.ndarray((87,100), buffer = np.array(x_train))
y_train = np.ndarray((87,8), buffer = np.array(y_train) )

# %%
model = Sequential()

model.add(Dense(87, input_dim=100, activation="tanh"))

model.add(Dense(100, activation="tanh"))

model.add(Dense(50, activation="tanh"))

model.add(Dense(8, activation="softmax"))

model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

print(model.summary())
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_98 (Dense)             (None, 87)                8787
# _________________________________________________________________
# dense_99 (Dense)             (None, 100)               8800
# _________________________________________________________________
# dense_100 (Dense)            (None, 50)                5050
# _________________________________________________________________
# dense_101 (Dense)            (None, 8)                 408
# ...
# Total params: 23,045
# Trainable params: 23,045
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(x_train, y_train, batch_size=87, epochs=2000, verbose=1)
# Out:
# Train on 87 samples
# Epoch 1/2000
# 87/87 [==============================] - 0s 3ms/sample - loss: 2.0414 - accuracy: 0.1034
# Epoch 2/2000
# 87/87 [==============================] - 0s 46us/sample - loss: 1.9674 - accuracy: 0.1494
# Epoch 3/2000
# 87/87 [==============================] - 0s 34us/sample - loss: 1.9142 - accuracy: 0.3563
# Epoch 4/2000
# 87/87 [==============================] - 0s 23us/sample - loss: 1.8754 - accuracy: 0.4023
# Epoch 5/2000
# 87/87 [==============================] - 0s 34us/sample - loss: 1.8462 - accuracy: 0.4023
# Epoch 6/2000
# 87/87 [==============================] - 0s 34us/sample - loss: 1.8233 - accuracy: 0.4023
# Epoch 7/2000
# 87/87 [==============================] - 0s 34us/sample - loss: 1.8046 - accuracy: 0.4023
# Epoch 8/2000
# 87/87 [==============================] - 0s 34us/sample - loss: 1.7887 - accuracy: 0.4023
# Epoch 9/2000
# 87/87 [==============================] - 0s 46us/sample - loss: 1.7748 - accuracy: 0.4023
# Epoch 10/2000
# ...

# %%
predictions = model.predict(x_train)

np.argmax(predictions[39])
# Out:
# 4

# %%
x_test = []
well = str(input())
SP = pd.read_csv('C://Users/SMA_9/Desktop/HW/OutData2/' + well +'.csv' )
x_test.append(SP.X.values)
x_test = np.ndarray((1,100), buffer = np.array(x_test))
prediction = model.predict(x_test)
np.argmax(prediction)
# Out:
# 3
